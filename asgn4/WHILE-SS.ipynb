# %% [markdown]
# # WHILE-SS - Assig
# Robert Sato
# rssato
# 1517254
# 2/1/2021

# %% [markdown]
# ### Syntactic changes:
# - aexp = ... | ( aexp )
# - bexp = ... | ( bexp )
# - comm = ... | { comm }
#
# ### To Do:
# - plan syntactic changes
# - plan representation of stores
# - test existing
# - make changes for parens
# - test new tokens
# - change output format
#
# ### Completed:
# -

# %%
INTEGER, PLUS, MINUS, MUL, LPAREN, RPAREN, LBRACE, RBRACE, ASSIGNMENT, VAR, TRUE, FALSE, SEMI_COLON, EOF= (
    'INTEGER', 'PLUS', 'MINUS', 'MUL', '(', ')', '{', '}', 'ASSIGNMENT', 'VAR', 'TRUE', 'FALSE', ';', 'EOF'
)
IF, THEN, ELSE, WHILE, DO, SKIP, NOT, LESS_THAN, EQUALS, OR, AND = (
    'IF', 'THEN', 'ELSE', 'WHILE', 'DO', 'SKIP', 'NOT', '<', '==', 'OR', 'AND'
)

# token class for representing all the different types of symbols
class Token(object):
    def __init__(self, type, value):
        self.type = type
        self.value = value
    def __repr__(self):
        return 'Token({type}, {value})'.format(
            type=self.type,
            value=repr(self.value)
        )

# %%
# "tokenize" the input string - convert the input text into a list of tokens
# accepts numbers, parenthesis, and arithmetic symbols
# Given: no decimal numbers and always 1 white space

class Lexer(object):
    def __init__(self, text):
        self.text = text
        self.pos = 0
        self.tokenList = self.tokenize()
        self.token_pos = 0
    
    # return a list of tokens
    def tokenize(self):
        textAsTokens = []
        print("tokenize()\nEquation: ", self.text)
        #print("Text has len: ", len(self.text))
        while self.pos < len(self.text):
            curr = self.text[self.pos]
            #print('curr =', curr)
            # setup conditionals for all cases
            if curr == ' ':
                self.pos += 1
                continue
            elif curr.isdigit():
                # keep adding digit chars until whitespace
                num = ''
                while curr.isdigit(): # keep appending
                    num += curr
                    self.pos += 1
                    if self.pos >= len(self.text):
                        break
                    curr = self.text[self.pos]
                self.pos -= 1
                # convert string of digits to int
                num = int(num)
                textAsTokens.append(Token(INTEGER, num))
            elif curr == '+':
                textAsTokens.append(Token(PLUS, curr))
            elif curr == '*':
                textAsTokens.append(Token(MUL, curr))
            elif curr == '-':
                # add functionality for negative numbers
                # if next char is a digit, do digit stuff and add as INTEGER
                next = self.text[self.pos+1]
                if next.isdigit():
                    print('found next is digit:', next)
                    # do digit stuff
                    self.pos += 1
                    curr = self.text[self.pos]
                    num = '-'
                    while curr.isdigit(): # keep appending
                        num += curr
                        self.pos += 1
                        if self.pos >= len(self.text):
                            break
                        curr = self.text[self.pos]
                    self.pos -= 1
                    # convert string of digits to int
                    num = int(num)
                    textAsTokens.append(Token(INTEGER, num))

                # elif a space, add as MINUS
                else:
                #elif next == ' ':
                    textAsTokens.append(Token(MINUS, curr))
                # elif a LPAREN -> ur screwed so ignore for now
            elif curr == '(':
                textAsTokens.append(Token(LPAREN, curr))
            elif curr == ')':
                textAsTokens.append(Token(RPAREN, curr))
            elif curr == '{':
                textAsTokens.append(Token(LBRACE, curr))
            elif curr == '}':
                textAsTokens.append(Token(RBRACE, curr))
            elif curr == '¬':
                textAsTokens.append(Token(NOT, curr))
            elif curr == '<':
                textAsTokens.append(Token(LESS_THAN, curr))
            elif curr == '=':
                textAsTokens.append(Token(EQUALS, curr))
            elif curr == '∨':
                textAsTokens.append(Token(OR, curr))
            elif curr == '∧':
                textAsTokens.append(Token(AND, curr))
            elif curr == ';':
                textAsTokens.append(Token(SEMI_COLON, curr))
            # assignment ':='
            elif curr == ':':
                next = self.text[self.pos+1]
                if next == '=':
                    textAsTokens.append(Token(ASSIGNMENT, ':='))
                    self.pos += 1
                else:
                    print("Error: no = following : in expected :=")
            
            # keywords
            # if
            elif curr == 'i' and (self.pos < len(self.text) - 1 and self.text[self.pos+1] == 'f'):
                # skip one and add if token
                self.pos += 1
                textAsTokens.append(Token(IF, 'if'))
            # then
            elif curr == 't' and (self.pos < len(self.text) - 3 and self.text[self.pos+1:self.pos+4] == 'hen'):
                self.pos += 3
                textAsTokens.append(Token(THEN, 'then'))

            # else
            elif curr == 'e' and (self.pos < len(self.text) - 3 and self.text[self.pos+1:self.pos+4] == 'lse'):
                self.pos += 3
                textAsTokens.append(Token(ELSE, 'else'))

            # while
            elif curr == 'w' and (self.pos < len(self.text) - 4 and self.text[self.pos+1:self.pos+5] == 'hile'):
                self.pos += 4
                textAsTokens.append(Token(WHILE, 'while'))

            # do
            elif curr == 'd' and (self.pos < len(self.text) - 1 and self.text[self.pos+1] == 'o'):
                self.pos += 1
                textAsTokens.append(Token(DO, 'do'))

            # skip
            elif curr == 's' and (self.pos < len(self.text) - 3 and self.text[self.pos+1:self.pos+4] == 'kip'):
                self.pos += 3
                textAsTokens.append(Token(SKIP, 'skip'))
            
            # true
            elif curr == 't' and (self.pos < len(self.text) - 3 and self.text[self.pos+1:self.pos+4] == 'rue'):
                self.pos += 3
                textAsTokens.append(Token(TRUE, 'true'))
            
            # false
            elif curr == 'f' and (self.pos < len(self.text) - 4 and self.text[self.pos+1:self.pos+5] == 'alse'):
                self.pos += 4
                textAsTokens.append(Token(FALSE, 'false'))

            # variable - check this after checking if 'true' 'false' 'if' etc.
            elif curr.isalpha():
                # all following characters except whitespace counts as the variable name
                var = ''
                while curr != ' ': # keep appending
                    var += curr
                    self.pos += 1
                    if self.pos >= len(self.text):
                        break
                    curr = self.text[self.pos]
                self.pos -= 1
                # convert string of digits to int
                textAsTokens.append(Token(VAR, var))

            else:
                print("Error found unknown symbol at '{}'".format(curr))
            
            self.pos += 1

        return textAsTokens
    
    # for the parser library
    def get_next_token(self):
        # can only be called after calling tokenize
        #print("Token list is size:", len(self.tokenList))
        if self.token_pos < len(self.tokenList):
            temp = self.tokenList[self.token_pos]
            self.token_pos += 1
            print("get_next_token() =", temp)
            return temp
        else:
            #print("No more tokens")
            return Token(EOF, None)
    
    def expr_is_bool(self):
        # this function will be called when current token is LPAREN
        # in if/while, when we are trying to determine if this paren is a bexpr or aexpr
        curr_pos = self.token_pos
        print("Checking what type of paren expr this is...")
        # scan over the tokens
        # skip tokens when more LPARENS are seen. stop skipping when that many RPARENS are seen
        skipping = 0
        is_bool = None
        curr_pos += 1 # first LPAREN will be skipped
        while curr_pos < len(self.tokenList):
            # save the last seen operator to define aexpr or bexpr
            # once RPAREN is found, return true if last seen expr = bexpr; false if last seen expr = aexpr
            curr_token = self.tokenList[curr_pos]
            #print("curr_token:", curr_token)
            if curr_token.type == LPAREN:
                skipping += 1
            elif curr_token.type == RPAREN:
                skipping -= 1
                if skipping == -1:
                    # done
                    if is_bool == None:
                        print("Error: is_bool never set. No operations seen")
                    return is_bool
            elif skipping == 0:
                print("checking token:", curr_token.type)
                # actually record if is_bool
                if curr_token.type in (TRUE, FALSE, NOT,LESS_THAN, EQUALS, OR, AND):
                    #print("is_bool set to True")
                    is_bool = True
                elif curr_token.type in (PLUS, MINUS, MUL):
                    #print("is_bool set to False")
                    is_bool = False
            #else:
            #    print("Skipping", curr_token, "because in parens; skipping =", skipping)

            curr_pos += 1
        print("Error: Reached EOF without finding matching RPAREN")
        return None


    def print(self):
        print("Text has len: ", len(self.text))
        while self.pos < len(self.text):
            print("{}:{}".format(self.pos, self.text[self.pos]))
            self.pos += 1

    def getNextChar(self):
        self.pos += 1
        return self.text[self.pos-1]

# %%
# testing expr_is_bool()
bools = '( ( x < 4 )  ∨ (( x + 2 ) < y ))'
bools = '( ( x - 3 ) + ( y + 2 ) )'
bools = '( ( 1 + 1 ) < 0 ) ∨ ( true )'

lexer = Lexer(bools)
if lexer.expr_is_bool():
    print("Bool!")
else:
    print("Aexpr!")
# Out:
# tokenize()
# Equation:  ( ( 1 + 1 ) < 0 ) ∨ ( true )
# Checking what type of paren expr this is...
# checking token: <
# checking token: INTEGER
# Bool!

# %%
formulas = []
formulas.append('x := 1')
formulas.append('x := (1 + 2) * 3; y := 3')
formulas.append('if 0 < x ∨ 4 < y then x := 1 else x := 3')

formulas.append('a := 98 ; b := 76 ; while ¬ ( a = b ) do { if a < b then b := b - a else a := a - b }')
formulas.append('while false do x := 1 ; y := 1')

formulas.append('if 3 < -3 then g := 3 + -2 else h := 09 + 9')
formulas.append('if ( false ∨ 3 < y + X ) then l := lv + -1 else x := -4 - z ; while -1 - p = 2 - -3 ∧ false do while ( ¬ ( 2 * -2 < y * y ) ) do skip')

for formula in formulas:
    lexer = Lexer(formula)
    token = lexer.get_next_token()
    while token.type != EOF:
        #print(token)
        token = lexer.get_next_token()
    print()
# Out:
# tokenize()
# Equation:  x := 1
# get_next_token() = Token(VAR, 'x')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(INTEGER, 1)
#
# tokenize()
# Equation:  x := (1 + 2) * 3; y := 3
# get_next_token() = Token(VAR, 'x')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token((, '(')
# get_next_token() = Token(INTEGER, 1)
# get_next_token() = Token(PLUS, '+')
# get_next_token() = Token(INTEGER, 2)
# get_next_token() = Token(), ')')
# get_next_token() = Token(MUL, '*')
# get_next_token() = Token(INTEGER, 3)
# get_next_token() = Token(;, ';')
# get_next_token() = Token(VAR, 'y')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(INTEGER, 3)
#
# tokenize()
# Equation:  if 0 < x ∨ 4 < y then x := 1 else x := 3
# get_next_token() = Token(IF, 'if')
# get_next_token() = Token(INTEGER, 0)
# get_next_token() = Token(<, '<')
# get_next_token() = Token(VAR, 'x')
# get_next_token() = Token(OR, '∨')
# get_next_token() = Token(INTEGER, 4)
# get_next_token() = Token(<, '<')
# get_next_token() = Token(VAR, 'y')
# get_next_token() = Token(THEN, 'then')
# get_next_token() = Token(VAR, 'x')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(INTEGER, 1)
# get_next_token() = Token(ELSE, 'else')
# get_next_token() = Token(VAR, 'x')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(INTEGER, 3)
#
# tokenize()
# Equation:  a := 98 ; b := 76 ; while ¬ ( a = b ) do { if a < b then b := b - a else a := a - b }
# get_next_token() = Token(VAR, 'a')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(INTEGER, 98)
# get_next_token() = Token(;, ';')
# get_next_token() = Token(VAR, 'b')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(INTEGER, 76)
# get_next_token() = Token(;, ';')
# get_next_token() = Token(WHILE, 'while')
# get_next_token() = Token(NOT, '¬')
# get_next_token() = Token((, '(')
# get_next_token() = Token(VAR, 'a')
# get_next_token() = Token(==, '=')
# get_next_token() = Token(VAR, 'b')
# get_next_token() = Token(), ')')
# get_next_token() = Token(DO, 'do')
# get_next_token() = Token({, '{')
# get_next_token() = Token(IF, 'if')
# get_next_token() = Token(VAR, 'a')
# get_next_token() = Token(<, '<')
# get_next_token() = Token(VAR, 'b')
# get_next_token() = Token(THEN, 'then')
# get_next_token() = Token(VAR, 'b')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(VAR, 'b')
# get_next_token() = Token(MINUS, '-')
# get_next_token() = Token(VAR, 'a')
# get_next_token() = Token(ELSE, 'else')
# get_next_token() = Token(VAR, 'a')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(VAR, 'a')
# get_next_token() = Token(MINUS, '-')
# get_next_token() = Token(VAR, 'b')
# get_next_token() = Token(}, '}')
#
# tokenize()
# Equation:  while false do x := 1 ; y := 1
# get_next_token() = Token(WHILE, 'while')
# get_next_token() = Token(FALSE, 'false')
# get_next_token() = Token(DO, 'do')
# get_next_token() = Token(VAR, 'x')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(INTEGER, 1)
# get_next_token() = Token(;, ';')
# get_next_token() = Token(VAR, 'y')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(INTEGER, 1)
#
# tokenize()
# Equation:  if 3 < -3 then g := 3 + -2 else h := 09 + 9
# found next is digit: 3
# found next is digit: 2
# get_next_token() = Token(IF, 'if')
# get_next_token() = Token(INTEGER, 3)
# get_next_token() = Token(<, '<')
# get_next_token() = Token(INTEGER, -3)
# get_next_token() = Token(THEN, 'then')
# get_next_token() = Token(VAR, 'g')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(INTEGER, 3)
# get_next_token() = Token(PLUS, '+')
# get_next_token() = Token(INTEGER, -2)
# get_next_token() = Token(ELSE, 'else')
# get_next_token() = Token(VAR, 'h')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(INTEGER, 9)
# get_next_token() = Token(PLUS, '+')
# get_next_token() = Token(INTEGER, 9)
#
# tokenize()
# Equation:  if ( false ∨ 3 < y + X ) then l := lv + -1 else x := -4 - z ; while -1 - p = 2 - -3 ∧ false do while ( ¬ ( 2 * -2 < y * y ) ) do skip
# found next is digit: 1
# found next is digit: 4
# found next is digit: 1
# found next is digit: 3
# found next is digit: 2
# get_next_token() = Token(IF, 'if')
# get_next_token() = Token((, '(')
# get_next_token() = Token(FALSE, 'false')
# get_next_token() = Token(OR, '∨')
# get_next_token() = Token(INTEGER, 3)
# get_next_token() = Token(<, '<')
# get_next_token() = Token(VAR, 'y')
# get_next_token() = Token(PLUS, '+')
# get_next_token() = Token(VAR, 'X')
# get_next_token() = Token(), ')')
# get_next_token() = Token(THEN, 'then')
# get_next_token() = Token(VAR, 'l')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(VAR, 'lv')
# get_next_token() = Token(PLUS, '+')
# get_next_token() = Token(INTEGER, -1)
# get_next_token() = Token(ELSE, 'else')
# get_next_token() = Token(VAR, 'x')
# get_next_token() = Token(ASSIGNMENT, ':=')
# get_next_token() = Token(INTEGER, -4)
# get_next_token() = Token(MINUS, '-')
# get_next_token() = Token(VAR, 'z')
# get_next_token() = Token(;, ';')
# get_next_token() = Token(WHILE, 'while')
# get_next_token() = Token(INTEGER, -1)
# get_next_token() = Token(MINUS, '-')
# get_next_token() = Token(VAR, 'p')
# get_next_token() = Token(==, '=')
# get_next_token() = Token(INTEGER, 2)
# get_next_token() = Token(MINUS, '-')
# get_next_token() = Token(INTEGER, -3)
# get_next_token() = Token(AND, '∧')
# get_next_token() = Token(FALSE, 'false')
# get_next_token() = Token(DO, 'do')
# get_next_token() = Token(WHILE, 'while')
# get_next_token() = Token((, '(')
# get_next_token() = Token(NOT, '¬')
# get_next_token() = Token((, '(')
# get_next_token() = Token(INTEGER, 2)
# get_next_token() = Token(MUL, '*')
# get_next_token() = Token(INTEGER, -2)
# get_next_token() = Token(<, '<')
# get_next_token() = Token(VAR, 'y')
# get_next_token() = Token(MUL, '*')
# get_next_token() = Token(VAR, 'y')
# get_next_token() = Token(), ')')
# get_next_token() = Token(), ')')
# get_next_token() = Token(DO, 'do')
# get_next_token() = Token(SKIP, 'skip')

# %%
# create an AST from the tokens
class AST(object):
    pass

class BinOp(AST):
    def __init__(self, left, op, right):
        self.left = left
        self.token = self.op = op
        self.right = right
    def __repr__(self):
        return '({}{}{})'.format(
            self.left, self.token.value, self.right
        )

class Num(AST):
    def __init__(self, token):
        self.token = token
        self.value = int(token.value)
    def __repr__(self):
        return '{value}'.format(
            value=repr(self.value)
        )

class Var(AST):
    def __init__(self, token):
        self.token = token
        self.value = token.value
    def __repr__(self):
        return self.value

# %%
# pretty printing for AExp
binop = BinOp(1, Token(PLUS, '+'), 2)
var = Var(Token(VAR, 's'))
print(var)
print(binop)
varop1 = BinOp(var, Token(MUL, '*'), 3)
print(varop1)
num = Num(Token(Num, '5'))
varop2 = BinOp(num, Token(MUL, '*'), varop1)
print(varop2)
# Out:
# s
# (1+2)
# (s*3)
# (5*(s*3))

# %%
# node types for boolean expressions
class BoolOp(AST):
    # handles cases for multiple boolean expressions
    def __init__(self, left, op, right):
        self.left = left
        # if expr comparison, the operation will be = or <
        # else it will be AND or OR
        self.token = self.op = op
        self.right = right
    def __repr__(self):
        return '({}{}{})'.format(
            self.left, self.token.value, self.right
        )
class BoolLeaf(AST):
    # handles single bool expr cases
    def __init__(self, token):
        self.token = token
        self.value = token.value
    def __repr__(self):
        return self.value

class Not(AST):
    def __init__(self, child):
        self.child = child
    def __repr__(self):
        return '¬{child}'.format(
            child=self.child
        )

# %%
# pretty printing for boolean expressions
tru = BoolLeaf(Token(TRUE, 'true'))
print(tru)

boolop = BoolOp(tru, Token(AND, '∧'), BoolLeaf(Token(FALSE, 'false')))
print(boolop)

nott = Not(tru)
print(nott)

boolop2 = BoolOp(nott, Token(AND, '∧'), boolop)
print(boolop2)
# Out:
# true
# (true∧false)
# ¬true
# (¬true∧(true∧false))

# %%
# node types for commands
class VarAssign(AST):
    # handles cases for multiple boolean expressions
    def __init__(self, name, value):
        self.name = name
        self.value = value
    def __repr__(self):
        return '{name} := {value}'.format(
            name = self.name,
            value = self.value
        )

class If(AST):
    # handles single bool expr cases
    def __init__(self, cond, true_branch, false_branch):
        self.cond = cond
        self.true_branch = true_branch
        self.false_branch = false_branch
    def __repr__(self):
        return 'if {cond} then {{ {t} }} else {{ {f} }}'.format(
            cond=repr(self.cond),
            t = repr(self.true_branch),
            f = repr(self.false_branch)
        )

class While(AST):
    def __init__(self, cond, true_branch):
        self.cond = cond,
        self.true_branch = true_branch
    def __repr__(self):
        return 'while {cond} do {{ {t} }}'.format(
            cond=self.cond,
            t=self.true_branch
        )

class Skip(AST):
    def __init__(self, token):
        self.token = token
    def __repr__(self):
        return 'skip'

class SEMI_COL(AST):
    def __init__(self, token, left, right):
        self.token = token
        self.left = left
        self.right = right
    def __repr__(self):
        return '{left}; {right}'.format(left=self.left, right=self.right)

# %%
commandpp = 'x := 3'
ifpp = 'if ( x < 5 ) then x := x + 1 else x := x - 1'
lexer = Lexer(commandpp)
token = lexer.get_next_token()
while token.type != EOF:
    print(token)
    token = lexer.get_next_token()

print()
print('{{ {} }}'.format('x'))
# Out:
# tokenize()
# Equation:  x := 3
# get_next_token() = Token(VAR, 'x')
# Token(VAR, 'x')
# get_next_token() = Token(ASSIGNMENT, ':=')
# Token(ASSIGNMENT, ':=')
# get_next_token() = Token(INTEGER, 3)
# Token(INTEGER, 3)
#
# { x }

# %%
'''
EBNF Grammer from for boolean expressions: https://unnikked.ga/how-to-build-a-boolean-expression-evaluator-518e9e068a65
<expression>::=<term>{<or><term>}
<term>::=<factor>{<and><factor>}
<factor>::=<constant>|<not><factor>|(<expression>)
<constant>::= false|true
<or>::='|'
<and>::='&'
<not>::='!'
'''
# Out:
# "\nEBNF Grammer from for boolean expressions: https://unnikked.ga/how-to-build-a-boolean-expression-evaluator-518e9e068a65\n<expression>::=<term>{<or><term>}\n<term>::=<factor>{<and><factor>}\n<factor>::=<constant>|<not><factor>|(<expression>)\n<constant>::= false|true\n<or>::='|'\n<and>::='&'\n<not>::='!'\n"

# %%
# Parser code from https://ruslanspivak.com/lsbasi-part7/ in references;
# changed for my list implementation of tokens
class Parser(object):
    def __init__(self, lexer):
        self.lexer = lexer
        # set current token to the first token taken from the input
        self.current_token = self.lexer.get_next_token()

    def error(self):
        raise Exception('Invalid syntax')

    def eat(self, token_type):
        # compare the current token type with the passed token
        # type and if they match then "eat" the current token
        # and assign the next token to the self.current_token,
        # otherwise raise an exception.
        print("Eating: type: {}, value: {}".format(self.current_token.type, self.current_token.value))
        if self.current_token.type == token_type:
            self.current_token = self.lexer.get_next_token()
        else:
            print("self.eat; Expected type: {} and got type: {}".format(self.current_token.type, token_type))
            self.error()

    def factor(self):
        """factor : INTEGER | LPAREN expr RPAREN"""
        token = self.current_token
        if token.type == INTEGER:
            self.eat(INTEGER)
            return Num(token)
        elif token.type == VAR:
            self.eat(VAR)
            return Var(token)
        elif token.type == LPAREN:
            self.eat(LPAREN)
            node = self.expr()
            self.eat(RPAREN)
            return node

    def term(self):
        """term : factor ((MUL) factor)*"""
        node = self.factor()

        while self.current_token.type in (MUL):
            token = self.current_token
            if token.type == MUL:
                self.eat(MUL)

            node = BinOp(left=node, op=token, right=self.factor())

        return node

    def expr(self):
        """
        expr   : term ((PLUS | MINUS) term)*
        term   : factor ((MUL | DIV) factor)*
        factor : INTEGER | LPAREN expr RPAREN
        """
        node = self.term()

        while self.current_token.type in (PLUS, MINUS):
            token = self.current_token
            if token.type == PLUS:
                self.eat(PLUS)
            elif token.type == MINUS:
                self.eat(MINUS)

            node = BinOp(left=node, op=token, right=self.term())

        return node


    # define a boolean expression type
    def b_expr(self):
        """
        <expression>::=<term>{<or><term>}
        """
        print('in b_expr()')
        print('current_token:', self.current_token)
        # first token in set (true, false, expr, not, b_expr)
        node = self.b_term()
        #print('self.current_token after b_expr call to b_term():', self.current_token)
        while self.current_token.type == OR:
            token = self.current_token
            self.eat(OR)
            node = BoolOp(left=node, op=token, right=self.b_term())
        return node

    def b_term(self):
        """
        <term>::=<factor>{<and><factor>}
        """
        print('in b_term()')
        print('current_token:', self.current_token)
        node = self.b_factor()
        while self.current_token.type == AND:
            token = self.current_token
            self.eat(AND)
            node = BoolOp(left=node, op=token, right=self.b_factor())
        return node
    
    def b_factor(self):
        """
        <factor>::=<constant>|<not><factor>|(<expression>)
        <constant>::= false|true
        """
        print('in b_factor()')
        print('current_token:', self.current_token)
        token = self.current_token
        if token.type == TRUE:
            self.eat(TRUE)
            return BoolLeaf(token)
        elif token.type == FALSE:
            self.eat(FALSE)
            return BoolLeaf(token)
        elif token.type == NOT:
            self.eat(NOT)
            node = self.b_factor()
            # node = self.b_expr() # this should prob be b_expr()
            node = Not(child=node)
            return node
        elif token.type == LPAREN:
            print("Looking at LPAREN\nNeed to check aexp/bexp")
            if self.lexer.expr_is_bool(): # eating parens is not handled in self.b_expr() call
                print("paren found to be BOOLEAN EXPR")
                self.eat(LPAREN)
                node = self.b_expr()
                self.eat(RPAREN)
            else: # eating parens handled with self.expr() call
                # should create a node and compare to the next aexpr
                print("paren NOT a BOOLEAN EXPR: should be aexpr")
                node = self.expr()
                token = self.current_token
                self.eat(token.type)
                node = BoolOp(left=node, op=token, right=self.expr())
            return node
        else: # comparisons
            #print("Error handling b_factor()")
            node = self.expr()
            token = self.current_token
            self.eat(token.type)
            #print("Comparison token is:", token)
            node = BoolOp(left=node, op=token, right=self.expr())
            return node

    # for commands
    # tree implementation
    # returns 1 command as its given object types
    def get_command(self):
        print("\nget_command()")
        if self.current_token.type != EOF:
            token = self.current_token
            type = token.type
            self.eat(type)
            if type == SKIP:
                print("adding skip command")
                return Skip(token)
            elif type == VAR:
                # syntax: VAR ASSIGNMENT EXPR
                name = token.value
                self.eat(ASSIGNMENT)
                expr = self.expr()
                print("Adding {} = expr() command".format(name))
                # don't need to eat bc self.expr() eats
                return VarAssign(name, expr)
            elif type == SEMI_COLON:
                # skip: command interpreter executes sequentially down list
                print("Error semicolon token given to get_command")
            elif type == IF:
                # syntax: IF b_expr THEN c_expr ELSE c_expr
                print("\nFinding condition for if()")
                cond = self.b_expr()
                # check if there is more to the bexpr (check if reached then)
                '''while self.current_token != THEN:
                    print("Not done with bexpr for if; finding another bexpr")
                    temp = self.current_token
                    self.eat(self.current_token.type)
                    cond = BoolOp(left=cond, op=temp, right=self.b_expr())'''
                self.eat(THEN)
                print("\nFinding true_branch for if()")
                true_branch = self.c_expr()
                self.eat(ELSE)
                print("\nFinding false_branch for if()")
                false_branch = self.c_expr()
                print("\nBack from IF false branch")
                print("Adding If node after calling b_expr and c_expr twice")
                return If(cond=cond, true_branch=true_branch, false_branch=false_branch)
            elif type == WHILE:
                # syntax: WHILE b_expr DO c_expr
                print("Finding condition for while()")
                cond = self.b_expr()
                self.eat(DO)
                print("Finding true_branch for while()")
                true_branch = self.c_expr()
                print("Adding While node after calling b_expr and c_expr")
                return While(cond=cond, true_branch=true_branch)
            # add condition for {}
            elif type == LBRACE:
                # syntax: { c_expr }
                print("Finding c_expr() inside { <-> } ")
                node = self.c_expr()
                self.eat(RBRACE)
                return node
            else:
                print("***Error: Unexpected token in c_expr()\n")

    def c_expr(self):
        node = self.get_command()
        while self.current_token.type == SEMI_COLON:
            # more commands to process
            self.eat(SEMI_COLON)
            node = SEMI_COL(SEMI_COLON, left=node, right=self.get_command())
        return node

    def parse(self):
        return self.c_expr()

# %%
#simple = 'x := 1 ; while ¬ ( x < 0 ) do x := 10'
#simple = 'a := 1 ; c := 2 ; HELLO := 10 ; b := a ; GOODBYE := 0'
simple = 'if x < 3 then x := 2 else if y < 4 then y := 4 else y := 5'
#simple = 'if ( 1 + 1 ) < 0 then z8 := 09 else z3 := 90'
#simple = 'if ( ( 1 + 1 ) < 0 ) ∨ ( true ) then z8 := 09 else z3 := 90'
lexer = Lexer(simple)
parser = Parser(lexer)
node = parser.parse()

print(node)
# Out:
# tokenize()
# Equation:  if x < 3 then x := 2 else if y < 4 then y := 4 else y := 5
# get_next_token() = Token(IF, 'if')
#
# get_command()
# Eating: type: IF, value: if
# get_next_token() = Token(VAR, 'x')
#
# Finding condition for if()
# in b_expr()
# current_token: Token(VAR, 'x')
# in b_term()
# current_token: Token(VAR, 'x')
# in b_factor()
# current_token: Token(VAR, 'x')
# Eating: type: VAR, value: x
# get_next_token() = Token(<, '<')
# Eating: type: <, value: <
# get_next_token() = Token(INTEGER, 3)
# Eating: type: INTEGER, value: 3
# get_next_token() = Token(THEN, 'then')
# Eating: type: THEN, value: then
# get_next_token() = Token(VAR, 'x')
#
# Finding true_branch for if()
#
# get_command()
# Eating: type: VAR, value: x
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 2)
# Eating: type: INTEGER, value: 2
# get_next_token() = Token(ELSE, 'else')
# Adding x = expr() command
# Eating: type: ELSE, value: else
# get_next_token() = Token(IF, 'if')
#
# Finding false_branch for if()
#
# get_command()
# Eating: type: IF, value: if
# get_next_token() = Token(VAR, 'y')
#
# Finding condition for if()
# in b_expr()
# current_token: Token(VAR, 'y')
# in b_term()
# current_token: Token(VAR, 'y')
# in b_factor()
# current_token: Token(VAR, 'y')
# Eating: type: VAR, value: y
# get_next_token() = Token(<, '<')
# Eating: type: <, value: <
# get_next_token() = Token(INTEGER, 4)
# Eating: type: INTEGER, value: 4
# get_next_token() = Token(THEN, 'then')
# Eating: type: THEN, value: then
# get_next_token() = Token(VAR, 'y')
#
# Finding true_branch for if()
#
# get_command()
# Eating: type: VAR, value: y
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 4)
# Eating: type: INTEGER, value: 4
# get_next_token() = Token(ELSE, 'else')
# Adding y = expr() command
# Eating: type: ELSE, value: else
# get_next_token() = Token(VAR, 'y')
#
# Finding false_branch for if()
#
# get_command()
# Eating: type: VAR, value: y
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 5)
# Eating: type: INTEGER, value: 5
# Adding y = expr() command
#
# Back from IF false branch
# Adding If node after calling b_expr and c_expr twice
#
# Back from IF false branch
# Adding If node after calling b_expr and c_expr twice
# if (x<3) then { x := 2 } else { if (y<4) then { y := 4 } else { y := 5 } }

# %% [markdown]
# # What is the form of commands?
# c := skip
#     | x := e
#     | c1 ; c2
#     | if b then c1 else c2
#     | while b do c1
#
# skip:
#     eat skip and call self again
#
# variable assignment:
#     create a variable assignment node
#     left = variable name
#     op = assignment
#     right = self.expr
#
# semicolon:
#     first command should have created a node by now
#     eat the semicolon and then call command handler again
#
# if:
#     create a if node
#     eat if, then and else in correct order
#     cond = self.b_expr
#     then = command handler
#     else = command handler
#
# while:
#     create a while node
#     eat while and do tokens in correct order
#     cond = self.b_expr
#     do = command handler
#
# new nodes to create
# - variable assignment, if, while, skip
#
# Implementation:
# - create a list of commands
#     - each element will be a command
#     - if semicolon, append a new command

# %%
# create an interpretor that does the computation given the AST
import collections

class Interpretor(object):
    def __init__(self, rootAST):
        self.rootAST = rootAST
        self.variables = {}

    def interpret(self):
        print("\ninterpreting 10,000 steps or until skip...")
        #self.visit(self.rootAST) # change this to visit 1000 or until skip command
        node = self.rootAST
        node_type = type(node).__name__
        steps = 0
        while steps < 10000 and node_type != 'Skip':
            node = self.visit(node)
            #print("Step:", steps, "Current node:", node)
            print('Formatted: Step {}; {}'.format(steps, node), end = ', ')
            self.printStore()
            steps += 1
            node_type = type(node).__name__

    def printStore(self):
        # print the store in the proper format
        count = 0
        print("{", end='')
        collection = collections.OrderedDict(sorted(self.variables.items()))
        for key in collection:
            if count > 0:
                print(', {key} → {value}'.format(key = key, value = collection[key]), end='')
            else:
                print('{key} → {value}'.format(key = key, value = collection[key]), end='')
            count += 1
        print("}")

    def visit(self, node):
        # very similar to our interpreter except print out the contents of the tree
        node_type = type(node).__name__
        # Arithmetic Expressions
        if node_type ==  'BinOp':
            #print("BinOp")
            if node.op.type == PLUS:
                return self.visit(node.left) + self.visit(node.right)
            elif node.op.type == MINUS:
                return self.visit(node.left) - self.visit(node.right)
            elif node.op.type == MUL:
                return self.visit(node.left) * self.visit(node.right)
        elif node_type == 'Num':
            return node.value
        elif node_type == 'Var':
            # look up the variable in the dictionary
            #print("Looking up a variable")
            val = self.variables.get(node.value, 0)
            while type(val).__name__ == 'VAR':
                val = self.variables.get(val.value, 0)
            return val
        
        # Boolean Expressions
        elif node_type == 'BoolOp':
            #print(node)
            if node.op.type == LESS_THAN:
                return self.visit(node.left) < self.visit(node.right)
            elif node.op.type == EQUALS:
                return self.visit(node.left) == self.visit(node.right)
            elif node.op.type == AND:
                return self.visit(node.left) and self.visit(node.right)
            elif node.op.type == OR:
                return self.visit(node.left) or self.visit(node.right)
            else:
                print("Error: Unknown op.type = {} in BoolOp", node.op.type)
        elif node_type == 'BoolLeaf':
            #print(node)
            if node.value == 'true':
                return True
            elif node.value == 'false':
                return False
            else:
                print("Error: Unknown node.value in BoolLeaf")
        elif node_type == 'Not':
            #print(node)
            return not self.visit(node.child)
        
        # Command Expressions
        elif node_type == 'VarAssign':
            #print(node)
            # add the variable name to dictionary
            var_name = node.name
            var_value  = node.value
            self.variables[var_name] = self.visit(var_value)
            return Skip(Token(SKIP, 'skip'))

        elif node_type == 'If':
            #print(node)
            if self.visit(node.cond):
                #self.visit(node.true_branch)
                return node.true_branch
            else:
                #self.visit(node.false_branch)
                return node.false_branch
        elif node_type == 'While':
            print(node)
            #while self.visit(node.cond):
            #    self.visit(node.true_branch)
            if self.visit(node.cond):
                # return c1 and same while command in a new semicol command
                return SEMI_COL(SEMI_COLON, left=node.true_branch, right=node)
            else:
                return Skip(Token(SKIP, 'skip'))

        elif node_type == 'Skip':
            print(node)
        elif node_type == 'SEMI_COL':
            #print(node)
            #self.visit(node.left)
            #self.visit(node.right)
            if type(node.left).__name__ == 'Skip':
                return node.right
            else:
                return SEMI_COL(SEMI_COLON, left=self.visit(node.left), right=node.right)
        elif node_type == 'tuple':
            print('Trying to unwrap bc tuple')
            return self.visit(node[0])
        else:
            print('{} node type not found in interpreter!!!'.format(node_type))

# %%
#simple = 'x := 1 ; while ¬ ( x < 0 ) do x := 10'
#simple = 'a := 1 ; c := 2 ; HELLO := 10 ; b := a ; GOODBYE := 0'
#simple = 'if x < 3 then x := 2 else if y < 4 then y := 4 else y := 5'
#simple = 'if ( 1 - 1 ) < 0 then z8 := 09 else z3 := 90'
simple = 'x := 3 ; if ( x < 5 ) then x := x + 1 else x := x - 1'
lexer = Lexer(simple)
parser = Parser(lexer)
node = parser.parse()
interpreter = Interpretor(node)
interpreter.interpret()
sorted(interpreter.variables.items(), key=lambda x: x[0])
sorted_list = []
for key, value in interpreter.variables.items():
    print('{key} → {value}'.format(key = key, value = value))
    sorted_list.append((key, value))

sorted(sorted_list, key=lambda x: x[0])
for pair in sorted_list:
    print(pair)
# Out:
# tokenize()
# Equation:  x := 3 ; if ( x < 5 ) then x := x + 1 else x := x - 1
# get_next_token() = Token(VAR, 'x')
#
# get_command()
# Eating: type: VAR, value: x
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 3)
# Eating: type: INTEGER, value: 3
# get_next_token() = Token(;, ';')
# Adding x = expr() command
# Eating: type: ;, value: ;
# get_next_token() = Token(IF, 'if')
#
# get_command()
# Eating: type: IF, value: if
# get_next_token() = Token((, '(')
#
# Finding condition for if()
# in b_expr()
# current_token: Token((, '(')
# in b_term()
# current_token: Token((, '(')
# in b_factor()
# current_token: Token((, '(')
# Looking at LPAREN
# Need to check aexp/bexp
# Checking what type of paren expr this is...
# checking token: <
# checking token: INTEGER
# paren found to be BOOLEAN EXPR
# Eating: type: (, value: (
# get_next_token() = Token(VAR, 'x')
# in b_expr()
# current_token: Token(VAR, 'x')
# in b_term()
# current_token: Token(VAR, 'x')
# in b_factor()
# current_token: Token(VAR, 'x')
# Eating: type: VAR, value: x
# get_next_token() = Token(<, '<')
# Eating: type: <, value: <
# get_next_token() = Token(INTEGER, 5)
# Eating: type: INTEGER, value: 5
# get_next_token() = Token(), ')')
# Eating: type: ), value: )
# get_next_token() = Token(THEN, 'then')
# Eating: type: THEN, value: then
# get_next_token() = Token(VAR, 'x')
#
# Finding true_branch for if()
#
# get_command()
# Eating: type: VAR, value: x
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(VAR, 'x')
# Eating: type: VAR, value: x
# get_next_token() = Token(PLUS, '+')
# Eating: type: PLUS, value: +
# get_next_token() = Token(INTEGER, 1)
# Eating: type: INTEGER, value: 1
# get_next_token() = Token(ELSE, 'else')
# Adding x = expr() command
# Eating: type: ELSE, value: else
# get_next_token() = Token(VAR, 'x')
#
# Finding false_branch for if()
#
# get_command()
# Eating: type: VAR, value: x
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(VAR, 'x')
# Eating: type: VAR, value: x
# get_next_token() = Token(MINUS, '-')
# Eating: type: MINUS, value: -
# get_next_token() = Token(INTEGER, 1)
# Eating: type: INTEGER, value: 1
# Adding x = expr() command
#
# Back from IF false branch
# Adding If node after calling b_expr and c_expr twice
#
# interpreting 10,000 steps or until skip...
# Formatted: Step 0; skip; if (x<5) then { x := (x+1) } else { x := (x-1) }, {x → 3}
# Formatted: Step 1; if (x<5) then { x := (x+1) } else { x := (x-1) }, {x → 3}
# Formatted: Step 2; x := (x+1), {x → 3}
# Formatted: Step 3; skip, {x → 4}
# x → 4
# ('x', 4)

# %%
for formula in formulas:
    lexer = Lexer(formula)
    parser = Parser(lexer)
    node = parser.parse()
    interpreter = Interpretor(node)
    interpreter.interpret()
    for key in interpreter.variables:
        print('{key} → {value}'.format(key = key, value = interpreter.variables[key]))
    print("\n\n")
# Out:
# tokenize()
# Equation:  x := 1
# get_next_token() = Token(VAR, 'x')
#
# get_command()
# Eating: type: VAR, value: x
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 1)
# Eating: type: INTEGER, value: 1
# Adding x = expr() command
#
# interpreting 10,000 steps or until skip...
# Formatted: Step 0; skip, {x → 1}
# x → 1
#
#
#
# tokenize()
# Equation:  x := (1 + 2) * 3; y := 3
# get_next_token() = Token(VAR, 'x')
#
# get_command()
# Eating: type: VAR, value: x
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token((, '(')
# Eating: type: (, value: (
# get_next_token() = Token(INTEGER, 1)
# Eating: type: INTEGER, value: 1
# get_next_token() = Token(PLUS, '+')
# Eating: type: PLUS, value: +
# get_next_token() = Token(INTEGER, 2)
# Eating: type: INTEGER, value: 2
# get_next_token() = Token(), ')')
# Eating: type: ), value: )
# get_next_token() = Token(MUL, '*')
# Eating: type: MUL, value: *
# get_next_token() = Token(INTEGER, 3)
# Eating: type: INTEGER, value: 3
# get_next_token() = Token(;, ';')
# Adding x = expr() command
# Eating: type: ;, value: ;
# get_next_token() = Token(VAR, 'y')
#
# get_command()
# Eating: type: VAR, value: y
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 3)
# Eating: type: INTEGER, value: 3
# Adding y = expr() command
#
# interpreting 10,000 steps or until skip...
# Formatted: Step 0; skip; y := 3, {x → 9}
# Formatted: Step 1; y := 3, {x → 9}
# Formatted: Step 2; skip, {x → 9, y → 3}
# x → 9
# y → 3
#
#
#
# tokenize()
# Equation:  if 0 < x ∨ 4 < y then x := 1 else x := 3
# get_next_token() = Token(IF, 'if')
#
# get_command()
# Eating: type: IF, value: if
# get_next_token() = Token(INTEGER, 0)
#
# Finding condition for if()
# in b_expr()
# current_token: Token(INTEGER, 0)
# in b_term()
# current_token: Token(INTEGER, 0)
# in b_factor()
# current_token: Token(INTEGER, 0)
# Eating: type: INTEGER, value: 0
# get_next_token() = Token(<, '<')
# Eating: type: <, value: <
# get_next_token() = Token(VAR, 'x')
# Eating: type: VAR, value: x
# get_next_token() = Token(OR, '∨')
# Eating: type: OR, value: ∨
# get_next_token() = Token(INTEGER, 4)
# in b_term()
# current_token: Token(INTEGER, 4)
# in b_factor()
# current_token: Token(INTEGER, 4)
# Eating: type: INTEGER, value: 4
# get_next_token() = Token(<, '<')
# Eating: type: <, value: <
# get_next_token() = Token(VAR, 'y')
# Eating: type: VAR, value: y
# get_next_token() = Token(THEN, 'then')
# Eating: type: THEN, value: then
# get_next_token() = Token(VAR, 'x')
#
# Finding true_branch for if()
#
# get_command()
# Eating: type: VAR, value: x
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 1)
# Eating: type: INTEGER, value: 1
# get_next_token() = Token(ELSE, 'else')
# Adding x = expr() command
# Eating: type: ELSE, value: else
# get_next_token() = Token(VAR, 'x')
#
# Finding false_branch for if()
#
# get_command()
# Eating: type: VAR, value: x
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 3)
# Eating: type: INTEGER, value: 3
# Adding x = expr() command
#
# Back from IF false branch
# Adding If node after calling b_expr and c_expr twice
#
# interpreting 10,000 steps or until skip...
# Formatted: Step 0; x := 3, {}
# Formatted: Step 1; skip, {x → 3}
# x → 3
#
#
#
# tokenize()
# Equation:  a := 98 ; b := 76 ; while ¬ ( a = b ) do { if a < b then b := b - a else a := a - b }
# get_next_token() = Token(VAR, 'a')
#
# get_command()
# Eating: type: VAR, value: a
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 98)
# Eating: type: INTEGER, value: 98
# get_next_token() = Token(;, ';')
# Adding a = expr() command
# Eating: type: ;, value: ;
# get_next_token() = Token(VAR, 'b')
#
# get_command()
# Eating: type: VAR, value: b
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 76)
# Eating: type: INTEGER, value: 76
# get_next_token() = Token(;, ';')
# Adding b = expr() command
# Eating: type: ;, value: ;
# get_next_token() = Token(WHILE, 'while')
#
# get_command()
# Eating: type: WHILE, value: while
# get_next_token() = Token(NOT, '¬')
# Finding condition for while()
# in b_expr()
# current_token: Token(NOT, '¬')
# in b_term()
# current_token: Token(NOT, '¬')
# in b_factor()
# current_token: Token(NOT, '¬')
# Eating: type: NOT, value: ¬
# get_next_token() = Token((, '(')
# in b_factor()
# current_token: Token((, '(')
# Looking at LPAREN
# Need to check aexp/bexp
# Checking what type of paren expr this is...
# checking token: ==
# checking token: VAR
# paren found to be BOOLEAN EXPR
# Eating: type: (, value: (
# get_next_token() = Token(VAR, 'a')
# in b_expr()
# current_token: Token(VAR, 'a')
# in b_term()
# current_token: Token(VAR, 'a')
# in b_factor()
# current_token: Token(VAR, 'a')
# Eating: type: VAR, value: a
# get_next_token() = Token(==, '=')
# Eating: type: ==, value: =
# get_next_token() = Token(VAR, 'b')
# Eating: type: VAR, value: b
# get_next_token() = Token(), ')')
# Eating: type: ), value: )
# get_next_token() = Token(DO, 'do')
# Eating: type: DO, value: do
# get_next_token() = Token({, '{')
# Finding true_branch for while()
#
# get_command()
# Eating: type: {, value: {
# get_next_token() = Token(IF, 'if')
# Finding c_expr() inside { <-> }
#
# get_command()
# Eating: type: IF, value: if
# get_next_token() = Token(VAR, 'a')
#
# Finding condition for if()
# in b_expr()
# current_token: Token(VAR, 'a')
# in b_term()
# current_token: Token(VAR, 'a')
# in b_factor()
# current_token: Token(VAR, 'a')
# Eating: type: VAR, value: a
# get_next_token() = Token(<, '<')
# Eating: type: <, value: <
# get_next_token() = Token(VAR, 'b')
# Eating: type: VAR, value: b
# get_next_token() = Token(THEN, 'then')
# Eating: type: THEN, value: then
# get_next_token() = Token(VAR, 'b')
#
# Finding true_branch for if()
#
# get_command()
# Eating: type: VAR, value: b
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(VAR, 'b')
# Eating: type: VAR, value: b
# get_next_token() = Token(MINUS, '-')
# Eating: type: MINUS, value: -
# get_next_token() = Token(VAR, 'a')
# Eating: type: VAR, value: a
# get_next_token() = Token(ELSE, 'else')
# Adding b = expr() command
# Eating: type: ELSE, value: else
# get_next_token() = Token(VAR, 'a')
#
# Finding false_branch for if()
#
# get_command()
# Eating: type: VAR, value: a
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(VAR, 'a')
# Eating: type: VAR, value: a
# get_next_token() = Token(MINUS, '-')
# Eating: type: MINUS, value: -
# get_next_token() = Token(VAR, 'b')
# Eating: type: VAR, value: b
# get_next_token() = Token(}, '}')
# Adding a = expr() command
#
# Back from IF false branch
# Adding If node after calling b_expr and c_expr twice
# Eating: type: }, value: }
# Adding While node after calling b_expr and c_expr
#
# interpreting 10,000 steps or until skip...
# Formatted: Step 0; skip; b := 76; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 98}
# Formatted: Step 1; b := 76; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 98}
# Formatted: Step 2; skip; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 98, b → 76}
# Formatted: Step 3; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 98, b → 76}
# while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }
# Trying to unwrap bc tuple
# Formatted: Step 4; if (a<b) then { b := (b-a) } else { a := (a-b) }; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 98, b → 76}
# Formatted: Step 5; a := (a-b); while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 98, b → 76}
# Formatted: Step 6; skip; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 76}
# Formatted: Step 7; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 76}
# while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }
# Trying to unwrap bc tuple
# Formatted: Step 8; if (a<b) then { b := (b-a) } else { a := (a-b) }; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 76}
# Formatted: Step 9; b := (b-a); while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 76}
# Formatted: Step 10; skip; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 54}
# Formatted: Step 11; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 54}
# while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }
# Trying to unwrap bc tuple
# Formatted: Step 12; if (a<b) then { b := (b-a) } else { a := (a-b) }; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 54}
# Formatted: Step 13; b := (b-a); while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 54}
# Formatted: Step 14; skip; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 32}
# Formatted: Step 15; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 32}
# while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }
# Trying to unwrap bc tuple
# Formatted: Step 16; if (a<b) then { b := (b-a) } else { a := (a-b) }; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 32}
# Formatted: Step 17; b := (b-a); while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 32}
# Formatted: Step 18; skip; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 10}
# Formatted: Step 19; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 10}
# while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }
# Trying to unwrap bc tuple
# Formatted: Step 20; if (a<b) then { b := (b-a) } else { a := (a-b) }; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 10}
# Formatted: Step 21; a := (a-b); while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 22, b → 10}
# Formatted: Step 22; skip; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 12, b → 10}
# Formatted: Step 23; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 12, b → 10}
# while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }
# Trying to unwrap bc tuple
# Formatted: Step 24; if (a<b) then { b := (b-a) } else { a := (a-b) }; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 12, b → 10}
# Formatted: Step 25; a := (a-b); while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 12, b → 10}
# Formatted: Step 26; skip; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 10}
# Formatted: Step 27; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 10}
# while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }
# Trying to unwrap bc tuple
# Formatted: Step 28; if (a<b) then { b := (b-a) } else { a := (a-b) }; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 10}
# Formatted: Step 29; b := (b-a); while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 10}
# Formatted: Step 30; skip; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 8}
# Formatted: Step 31; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 8}
# while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }
# Trying to unwrap bc tuple
# Formatted: Step 32; if (a<b) then { b := (b-a) } else { a := (a-b) }; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 8}
# Formatted: Step 33; b := (b-a); while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 8}
# Formatted: Step 34; skip; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 6}
# Formatted: Step 35; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 6}
# while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }
# Trying to unwrap bc tuple
# Formatted: Step 36; if (a<b) then { b := (b-a) } else { a := (a-b) }; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 6}
# Formatted: Step 37; b := (b-a); while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 6}
# Formatted: Step 38; skip; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 4}
# Formatted: Step 39; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 4}
# while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }
# Trying to unwrap bc tuple
# Formatted: Step 40; if (a<b) then { b := (b-a) } else { a := (a-b) }; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 4}
# Formatted: Step 41; b := (b-a); while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 4}
# Formatted: Step 42; skip; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 2}
# Formatted: Step 43; while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }, {a → 2, b → 2}
# while (¬(a=b),) do { if (a<b) then { b := (b-a) } else { a := (a-b) } }
# Trying to unwrap bc tuple
# Formatted: Step 44; skip, {a → 2, b → 2}
# a → 2
# b → 2
#
#
#
# tokenize()
# Equation:  while false do x := 1 ; y := 1
# get_next_token() = Token(WHILE, 'while')
#
# get_command()
# Eating: type: WHILE, value: while
# get_next_token() = Token(FALSE, 'false')
# Finding condition for while()
# in b_expr()
# current_token: Token(FALSE, 'false')
# in b_term()
# current_token: Token(FALSE, 'false')
# in b_factor()
# current_token: Token(FALSE, 'false')
# Eating: type: FALSE, value: false
# get_next_token() = Token(DO, 'do')
# Eating: type: DO, value: do
# get_next_token() = Token(VAR, 'x')
# Finding true_branch for while()
#
# get_command()
# Eating: type: VAR, value: x
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 1)
# Eating: type: INTEGER, value: 1
# get_next_token() = Token(;, ';')
# Adding x = expr() command
# Eating: type: ;, value: ;
# get_next_token() = Token(VAR, 'y')
#
# get_command()
# Eating: type: VAR, value: y
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 1)
# Eating: type: INTEGER, value: 1
# Adding y = expr() command
# Adding While node after calling b_expr and c_expr
#
# interpreting 10,000 steps or until skip...
# while (false,) do { x := 1; y := 1 }
# Trying to unwrap bc tuple
# Formatted: Step 0; skip, {}
#
#
#
# tokenize()
# Equation:  if 3 < -3 then g := 3 + -2 else h := 09 + 9
# found next is digit: 3
# found next is digit: 2
# get_next_token() = Token(IF, 'if')
#
# get_command()
# Eating: type: IF, value: if
# get_next_token() = Token(INTEGER, 3)
#
# Finding condition for if()
# in b_expr()
# current_token: Token(INTEGER, 3)
# in b_term()
# current_token: Token(INTEGER, 3)
# in b_factor()
# current_token: Token(INTEGER, 3)
# Eating: type: INTEGER, value: 3
# get_next_token() = Token(<, '<')
# Eating: type: <, value: <
# get_next_token() = Token(INTEGER, -3)
# Eating: type: INTEGER, value: -3
# get_next_token() = Token(THEN, 'then')
# Eating: type: THEN, value: then
# get_next_token() = Token(VAR, 'g')
#
# Finding true_branch for if()
#
# get_command()
# Eating: type: VAR, value: g
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 3)
# Eating: type: INTEGER, value: 3
# get_next_token() = Token(PLUS, '+')
# Eating: type: PLUS, value: +
# get_next_token() = Token(INTEGER, -2)
# Eating: type: INTEGER, value: -2
# get_next_token() = Token(ELSE, 'else')
# Adding g = expr() command
# Eating: type: ELSE, value: else
# get_next_token() = Token(VAR, 'h')
#
# Finding false_branch for if()
#
# get_command()
# Eating: type: VAR, value: h
# get_next_token() = Token(ASSIGNMENT, ':=')
# Eating: type: ASSIGNMENT, value: :=
# get_next_token() = Token(INTEGER, 9)
# Eating: type: INTEGER, value: 9
# get_next_token() = Token(PLUS, '+')
# Eating: type: PLUS, value: +
# get_next_token() = Token(INTEGER, 9)
# Eating: type: INTEGER, value: 9
# Adding h = expr() command
#
# Back from IF false branch
# Adding If node after calling b_expr and c_expr twice
#
# interpreting 10,000 steps or until skip...
# Formatted: Step 0; h := (9+9), {}
# Formatted: Step 1; skip, {h → 18}
# h → 18
#
#
#
# tokenize()
# Equation:  if ( false ∨ 3 < y + X ) then l := lv + -1 else x := -4 - z ; while -1 - p = 2 - -3 ∧ false do while ( ¬ ( 2 * -2 < y * y ) ) do skip
# found next is digit: 1
# found next is digit: 4
# found next is digit: 1
# found next is digit: 3
# found next is digit: 2
# get_next_token() = Token(IF, 'if')
#
# get_command()
# Eating: type: IF, value: if
# get_next_token() = Token((, '(')
#
# Finding condition for if()
# in b_expr()
# current_token: Token((, '(')
# in b_term()
# current_token: Token((, '(')
# in b_factor()
# current_token: Token((, '(')
# Looking at LPAREN
# Need to check aexp/bexp
# Checking what type of paren expr this is...
# checking token: OR
# checking token: INTEGER
# checking token: <
# checking token: VAR
# checking token: PLUS
# checking token: VAR
# paren NOT a BOOLEAN EXPR: should be aexpr
# Eating: type: (, value: (
# get_next_token() = Token(FALSE, 'false')
# Eating: type: FALSE, value: false
# self.eat; Expected type: FALSE and got type: )
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-138-028eee8eee6a> in <module>
#       2     lexer = Lexer(formula)
#       3     parser = Parser(lexer)
# ----> 4     node = parser.parse()
#       5     interpreter = Interpretor(node)
#       6     interpreter.interpret()
#
# <ipython-input-61-b4403d0794f6> in parse(self)
#     213
#     214     def parse(self):
# --> 215         return self.c_expr()
#
# <ipython-input-61-b4403d0794f6> in c_expr(self)
#     205
#     206     def c_expr(self):
# --> 207         node = self.get_command()
#     208         while self.current_token.type == SEMI_COLON:
#     209             # more commands to process
#
# <ipython-input-61-b4403d0794f6> in get_command(self)
#     169                 # syntax: IF b_expr THEN c_expr ELSE c_expr
#     170                 print("\nFinding condition for if()")
# --> 171                 cond = self.b_expr()
#     172                 # check if there is more to the bexpr (check if reached then)
#     173                 '''while self.current_token != THEN:
#
# <ipython-input-61-b4403d0794f6> in b_expr(self)
#      78         print('current_token:', self.current_token)
#      79         # first token in set (true, false, expr, not, b_expr)
# ---> 80         node = self.b_term()
#      81         #print('self.current_token after b_expr call to b_term():', self.current_token)
#      82         while self.current_token.type == OR:
#
# <ipython-input-61-b4403d0794f6> in b_term(self)
#      92         print('in b_term()')
#      93         print('current_token:', self.current_token)
# ---> 94         node = self.b_factor()
#      95         while self.current_token.type == AND:
#      96             token = self.current_token
#
# <ipython-input-61-b4403d0794f6> in b_factor(self)
#     129                 # should create a node and compare to the next aexpr
#     130                 print("paren NOT a BOOLEAN EXPR: should be aexpr")
# --> 131                 node = self.expr()
#     132                 token = self.current_token
#     133                 self.eat(token.type)
#
# <ipython-input-61-b4403d0794f6> in expr(self)
#      56         factor : INTEGER | LPAREN expr RPAREN
#      57         """
# ---> 58         node = self.term()
#      59
#      60         while self.current_token.type in (PLUS, MINUS):
#
# <ipython-input-61-b4403d0794f6> in term(self)
#      39     def term(self):
#      40         """term : factor ((MUL) factor)*"""
# ---> 41         node = self.factor()
#      42
#      43         while self.current_token.type in (MUL):
#
# <ipython-input-61-b4403d0794f6> in factor(self)
#      34             self.eat(LPAREN)
#      35             node = self.expr()
# ---> 36             self.eat(RPAREN)
#      37             return node
#      38
#
# <ipython-input-61-b4403d0794f6> in eat(self, token_type)
#      20         else:
#      21             print("self.eat; Expected type: {} and got type: {}".format(self.current_token.type, token_type))
# ---> 22             self.error()
#      23
#      24     def factor(self):
#
# <ipython-input-61-b4403d0794f6> in error(self)
#       8
#       9     def error(self):
# ---> 10         raise Exception('Invalid syntax')
#      11
#      12     def eat(self, token_type):
#
# Exception: Invalid syntax
